# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt

# %%
uniform = np.random.rand(10000)
normal = np.random.randn(10000)

fig = plt.figure(figsize=(14,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
ax1.hist(uniform, 20)
ax1.set_title('Uniform data')
ax2.hist(normal, 20)
ax2.set_title('Normal data')
fig.tight_layout()

# %%
np.mean(normal)
# Out:
# 0.007724667652628895

# %%
nmeans

# %%
for i in range(1000, 1500):
    umeans = []
    nmeans = []
    plt.close()
    for j in range(i):
        usamples = np.random.choice(uniform, 50, replace=False)
        nsamples = np.random.choice(normal, 50, replace=False)
        umeans.append(np.mean(usamples))
        nmeans.append(np.mean(nsamples))
    plt.hist(umeans)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6184\2459691967.py in <module>
#       8         umeans.append(np.mean(usamples))
#       9         nmeans.append(np.mean(nsamples))
# ---> 10     plt.hist(umeans)
#      11     plt.show()
#      12
#
# ~\.conda\envs\DAB300a\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2588         orientation='vertical', rwidth=None, log=False, color=None,
#    2589         label=None, stacked=False, *, data=None, **kwargs):
# -> 2590     return gca().hist(
#    2591         x, bins=bins, range=range, density=density, weights=weights,
#    2592         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ...
